# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from scipy import stats

# %%
df = pd.read_csv('Automobile.csv')
df.head(3)
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa

# %%
avg_by_year = df.groupby(['model_year']).agg({'cylinders': 'max', 
                          'mpg': 'max', 'horsepower': 'max'})

# %%
avg_by_year.head(3)
# Out:
#             cylinders   mpg  horsepower
# model_year
# 70                  8  27.0       225.0
# 71                  8  35.0       180.0
# 72                  8  28.0       208.0

# %%
scaler = preprocessing.MinMaxScaler()

# %%
avg_by_year[['cylinders', 'mpg', 'horsepower']] = scaler.fit_transform(avg_by_year[['cylinders', 'mpg', 'horsepower']])

avg_by_year.head(3)
# Out:
#             cylinders       mpg  horsepower
# model_year
# 70                1.0  0.000000    0.957627
# 71                1.0  0.408163    0.576271
# 72                1.0  0.051020    0.813559

# %%
avg_by_year.plot()
plt.show()

# %%
xmin, xmax = 0, 10
x = np.linspace(xmin, xmax, 200)

# %%
fig, ax = plt.subplots(figsize=(7,5))
cylinders = stats.norm.pdf(x, np.mean(df['cylinders']),  np.std(df['cylinders']))
ax.plot(x, cylinders, 'r', label = 'cylinders') 
ax.axvline(np.mean(df['cylinders']), color = 'r', linestyle= '--' )
ax.legend()
ax.set_xlabel('AutoMobile')
# Out:
# Text(0.5, 0, 'AutoMobile')

# %%
xmin, xmax = 0, 220
x = np.linspace(xmin, xmax, 500)

# %%
fig, ax = plt.subplots(figsize=(7,5))
horsepower = stats.norm.pdf(x, np.mean(df['horsepower']),  np.std(df['horsepower']))
ax.plot(x, horsepower, 'b', label = 'horsepower') 
ax.legend()
ax.set_xlabel('AutoMobile')
# Out:
# Text(0.5, 0, 'AutoMobile')

# %% [markdown]
# # masoud mapar
