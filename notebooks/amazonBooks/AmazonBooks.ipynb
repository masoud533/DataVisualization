# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('AmazonBooks.xlsx')
df.head(3)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         600 non-null    object
#  1   Author       600 non-null    object
#  2   User Rating  600 non-null    float64
#  3   Reviews      600 non-null    int64
#  4   Price        600 non-null    int64
#  5   Year         600 non-null    int64
#  6   Genre        600 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 32.9+ KB

# %%
np.shape(df)
# Out:
# (600, 7)

# %%
df.isna().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
fig, ax = plt.subplots()
ax.scatter(x=df['Reviews'], y=df['User Rating'], c=df['User Rating'])
ax.set(xlabel='Reviews', ylabel='User Rating')
# Out:
# [Text(0.5, 0, 'Reviews'), Text(0, 0.5, 'User Rating')]

# %%
fig, ax1 = plt.subplots(figsize=(8,6))
ax1.scatter(x=df['Price'], y=df['User Rating'], alpha=0.5, c=df['Price'])
ax1.set_xlabel('Price', size=16)
ax1.set_ylabel('User Rating', size=16)
ax1.xaxis.set_major_formatter('${x:,.0f}')
ax1.tick_params(axis='x', labelrotation=50, labelsize=12)
ax1.tick_params(axis='y', labelsize=12)
ax1.grid(True)

# %%
avg_by_year = df.groupby(['Year']).agg({'User Rating': 'mean', 
                          'Reviews': 'mean', 'Price': 'mean'})
avg_by_year.head(10)
# Out:
#       User Rating   Reviews  Price
# Year
# 2009        4.584   4710.12  15.40
# 2010        4.558   5479.62  13.48
# 2011        4.558   8100.82  15.10
# 2012        4.532  13090.92  15.30
# 2013        4.554  13098.14  14.60
# 2014        4.622  15859.94  14.64
# 2015        4.648  14233.38  10.42
# 2016        4.678  14196.00  13.18
# 2017        4.660  12888.40  11.38
# 2018        4.668  13930.42  10.52

# %%
avg_by_year['Reviews'].plot(kind='line', title='Reviews')
# Out:
# <AxesSubplot: title={'center': 'Reviews'}, xlabel='Year'>

# %%
avg_by_year['Price'].plot(kind='line', title='Price')
# Out:
# <AxesSubplot: title={'center': 'Price'}, xlabel='Year'>

# %%
avg_by_year['User Rating'].plot(kind='line', title='User Rating')
# Out:
# <AxesSubplot: title={'center': 'User Rating'}, xlabel='Year'>
